# %%
import re
import time
import urllib3
import requests
import pandas as pd
from bs4 import BeautifulSoup
from collections import defaultdict

urllib3.disable_warnings() # Fix the warnings!
from collections import Counter
import nltk
import string
from nltk.tokenize import word_tokenize
# Out:
# C:\Users\Dessy\anaconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
base = 'https://scholarshipdb.net/PhD-scholarships-in-United-States?page=2'
html_text = requests.get(base, verify=False)
soup = BeautifulSoup(html_text.content, "html.parser")

# %%
prefix = "https://scholarshipdb.net/"
webpage_response = requests.get('https://scholarshipdb.net/PhD-scholarships-in-United-States?page=2', verify=False)

webpage = webpage_response.content
soup = BeautifulSoup(webpage, "html.parser")

university_links = soup.find_all("a")
links = []
#go through all of the a tags and get the links associated with them"
for a in university_links:
  links.append(prefix+a["href"])

# %%
links
# Out:
# ['https://scholarshipdb.net//',
#  'https://scholarshipdb.net//PhD-scholarships',
#  'https://scholarshipdb.net//Postdoctoral-scholarships',
#  'https://scholarshipdb.net//scholarships/Program-Master',
#  'https://scholarshipdb.net//scholarships/Program-Undergraduate',
#  'https://scholarshipdb.net//scholarships/Tags-Featured',
#  'https://scholarshipdb.net//universities',
#  'https://scholarshipdb.net//blogs',
#  'https://scholarshipdb.net//scholarships-browse',
#  'https://scholarshipdb.net//users/sign_in',
#  'https://scholarshipdb.net/#',
#  'https://scholarshipdb.net//PhD-scholarships',
#  'https://scholarshipdb.net//Postdoctoral-scholarships',
#  'https://scholarshipdb.net//Master-scholarships',
#  'https://scholarshipdb.net//Undergraduate-scholarships',
#  'https://scholarshipdb.net//universities',
#  'https://scholarshipdb.net//scholarships-browse',
#  'https://scholarshipdb.net//users/sign_in',
#  'https://scholarshipdb.net/#filters',
# ...
