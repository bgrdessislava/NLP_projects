# %%
import urllib3
import requests
import itertools
import pandas as pd
from bs4 import BeautifulSoup

urllib3.disable_warnings() # Fix the warnings!

# %%
base = 'https://scholarshipdb.net/PhD-scholarships'

# %%
#This gets the website that we want to take in
html_text = requests.get(base, verify=False)
# Create a parser instance able to parse invalid markup.
soup = BeautifulSoup(html_text.text, 'html.parser')
#makes empty lists that will have the countries, fields and programmes
countries_all = []
fields = []
institutes = []
programmes = ([
    'PhD', 'Postdoctoral', 'Fellowship', 'Postgraduate', 
    'Master', 'Undergraduate', 'Coursework'
])
#Find all the lines that starts with 'a'
for link in soup.find_all('a'):
   #This gives you the all the URLs dound within a page's <a> tags
    url = link.get('href')
    #I am not sure 
    if url.startswith('/scholarships-in'):
        # So go through the URL from 17 to -6?
        country = url[17:-6]
        print(url)
# Out:
# /scholarships-in-United-States?q=PhD
# /scholarships-in-United-Kingdom?q=PhD
# /scholarships-in-Netherlands?q=PhD
# /scholarships-in-Australia?q=PhD
# /scholarships-in-Canada?q=PhD
# /scholarships-in-Germany?q=PhD
# /scholarships-in-Singapore?q=PhD
# /scholarships-in-Sweden?q=PhD
# /scholarships-in-Belgium?q=PhD
# /scholarships-in-Portugal?q=PhD
# /scholarships-in-Norway?q=PhD
# /scholarships-in-Switzerland?q=PhD
# /scholarships-in-France?q=PhD
# /scholarships-in-Denmark?q=PhD
# /scholarships-in-Spain?q=PhD
# /scholarships-in-New-Zealand?q=PhD
# /scholarships-in-Ireland?q=PhD
# /scholarships-in-Poland?q=PhD
# /scholarships-in-Europe?q=PhD
# /scholarships-in-Austria?q=PhD
# /scholarships-in-China?q=PhD
# /scholarships-in-Luxembourg?q=PhD
# /scholarships-in-Italy?q=PhD
# /scholarships-in-United-Arab-Emirates?q=PhD
# /scholarships-in-Finland?q=PhD
# /scholarships-in-Czech?q=PhD
# /scholarships-in-Hong-Kong?q=PhD
# /scholarships-in-Croatia?q=PhD
# /scholarships-in-Egypt?q=PhD
# /scholarships-in-Laos?q=PhD
# /scholarships-in-Suriname?q=PhD
# /scholarships-in-Estonia?q=PhD
# /scholarships-in-Romania?q=PhD
# /scholarships-in-Greece?q=PhD
# /scholarships-in-Slovenia?q=PhD
# /scholarships-in-Sao-Tome-and-Principe?q=PhD
# /scholarships-in-India?q=PhD
# /scholarships-in-Brazil?q=PhD
# /scholarships-in-Bulgaria?q=PhD
# /scholarships-in-Russia?q=PhD
# /scholarships-in-South-Africa?q=PhD
# /scholarships-in-Qatar?q=PhD
# /scholarships-in-Saudi-Arabia?q=PhD
# /scholarships-in-Cyprus?q=PhD
# /scholarships-in-Hungary?q=PhD
# /scholarships-in-Israel?q=PhD
# /scholarships-in-Macau?q=PhD
# /scholarships-in-Kazakhstan?q=PhD
# /scholarships-in-Malta?q=PhD
# /scholarships-in-Niue?q=PhD
# /scholarships-in-Česko?q=PhD
# /scholarships-in-Faroe-Islands?q=PhD
# /scholarships-in-Iceland?q=PhD
# /scholarships-in-Latvia?q=PhD
# /scholarships-in-Slovakia?q=PhD
# /scholarships-in-Malaysia?q=PhD
# /scholarships-in-Mexico?q=PhD
# /scholarships-in-South-Korea?q=PhD
# /scholarships-in-Tonga?q=PhD
# /scholarships-in-Albania?q=PhD
# /scholarships-in-Argentina?q=PhD
# /scholarships-in-Armenia?q=PhD
# /scholarships-in-Brunei?q=PhD
# /scholarships-in-Japan?q=PhD
# /scholarships-in-Taiwan?q=PhD
# /scholarships-in-Turkey?q=PhD
# /scholarships-in-Vietnam?q=PhD
# /scholarships-in-Andorra?q=PhD
# /scholarships-in-Brasil?q=PhD
# /scholarships-in-Colombia?q=PhD
# /scholarships-in-Isle-of-Man?q=PhD
# /scholarships-in-Kenya?q=PhD
# /scholarships-in-Netherlands-Antilles?q=PhD
# /scholarships-in-Pakistan?q=PhD
# /scholarships-in-Serbia?q=PhD
# /scholarships-in-Bangladesh?q=PhD
# /scholarships-in-Benin?q=PhD
# /scholarships-in-Cameroon?q=PhD
# /scholarships-in-China-/-Israel?q=PhD
# /scholarships-in-Deutschland?q=PhD
# /scholarships-in-España?q=PhD
# /scholarships-in-Ethiopia?q=PhD
# /scholarships-in-Fiji?q=PhD
# /scholarships-in-France,-Belgium,-Slovenia,-Spain,-Sweden,-United-Kingdom?q=PhD
# /scholarships-in-Germany,UK?q=PhD
# /scholarships-in-Gibraltar?q=PhD
# /scholarships-in-Iran?q=PhD
# /scholarships-in-Jersey?q=PhD
# /scholarships-in-Jordan?q=PhD
# /scholarships-in-Liechtenstein?q=PhD
# /scholarships-in-Lithuania?q=PhD
# /scholarships-in-Norge?q=PhD
# /scholarships-in-South-korea?q=PhD
# /scholarships-in-Uzbekistan?q=PhD
# /scholarships-in-Vienna,-Austria?q=PhD
# /scholarships-in-Australia
# /scholarships-in-United-Kingdom/Ph-D-Studentship-The-University-Of-Manchester=DbX4PVRa7RGUYQAlkGUTnw.html
# /scholarships-in-United-Kingdom
# /scholarships-in-Australia/Ph-D-Scholarship-University-Of-Melbourne=VHNaEVdZ7RGUYQAlkGUTnw.html
# /scholarships-in-Australia
# /scholarships-in-Germany/Ph-D-In-Nanophysics-Universit-t-M-nster=mClZ1wFZ7RGUYQAlkGUTnw.html
# /scholarships-in-Germany
# /scholarships-in-Australia/Ph-D-Scholarship-For-Nanothermometry-University-Of-Technology-Sydney=7mPjpkFb7RGUYQAlkGUTnw.html
# /scholarships-in-Australia
# /scholarships-in-Greece/Ph-D-Student-Biomedical-Sciences-Research-Centre-Alexander-Fleming=BB9DNlRZ7RGUYQAlkGUTnw.html
# /scholarships-in-Greece
# /scholarships-in-Spain/Ph-D-Student-University-Of-A-Coru-a=U9UA61VZ7RGUYQAlkGUTnw.html
# /scholarships-in-Spain
# /scholarships-in-United-Kingdom/Ph-D-Studentship-Clara-Collet-Scholarship-Ucl=f7s_8VRa7RGUYQAlkGUTnw.html
# /scholarships-in-United-Kingdom
# /scholarships-in-United-Kingdom/Ph-D-Studentship-In-Linguistics-University-Of-Reading=hdL0S1Ra7RGUYQAlkGUTnw.html
# /scholarships-in-United-Kingdom
# /scholarships-in-United-Kingdom/Ph-D-Studentship-In-Psychology-University-Of-Reading=6RasK1Ra7RGUYQAlkGUTnw.html
# /scholarships-in-United-Kingdom
# /scholarships-in-Spain/P-Hd-Candidate-Fundaci-Hospital-Universitari-Vall-D-Hebron-Institut-De-Recerca=Dpcz7XxV7RGUYQAlkGUTnw.html
# /scholarships-in-Spain

# %%
#This gets the website that we want to take in
html_text = requests.get(base, verify=False)
# Create a parser instance able to parse invalid markup.
soup = BeautifulSoup(html_text.text, 'html.parser')
#makes empty lists that will have the countries, fields and programmes
countries_all = []
fields = []
institutes = []
programmes = ([
    'PhD', 'Postdoctoral', 'Fellowship', 'Postgraduate', 
    'Master', 'Undergraduate', 'Coursework'
])
#Find all the lines that starts with 'a'
for link in soup.find_all('a'):
    #This gives you the all the URLs dound within a page's <a> tags
    url = link.get('href')
    #I am not sure 
    if url.startswith('/scholarships-in'):
        # So go through the URL from 17 to -6?
        country = url[17:-6]
        #If there is comma in the country then split them into each of the countries
        if ',' in country:
            #Split the countries to be different for each of the , - and then extend it to the list 
            countries_all.extend(country.split(',-'))
        else:
            #Not sure what is the difference but it also appends to the country list
            countries_all.append(country)
    elif url.startswith('/scholarships?q='):
        if not url.startswith('/scholarships?q=PhD&'):
            fields.append(url[16:])

# Clean up country list
countries = []
for country in countries_all:
    if ('=' in country) or (len(country) < 2):
        break
    countries.append(country)

# %%
combos = list(itertools.product(countries, programmes, fields))
print(combos)

# %%
data = []
url = 'https://scholarshipdb.net/scholarships-in-{}/Program-{}?q={}'
for i, (country, programme, field) in enumerate(combos):
    html_text = requests.get(url.format(country, programme, field), verify=False)
    soup = BeautifulSoup(html_text.text, 'html.parser')
    try:
        count = int(soup.title.text.split()[0].replace(',', ''))
    except:
        count = 0
    data.append([country, programme, field, count])
    if i % 100 == 0:
        print(i)
records = pd.DataFrame(data, columns=['country', 'programme', 'field', 'count'])
records.to_csv('all-scholarships.csv', index=False)
